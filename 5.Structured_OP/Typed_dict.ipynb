# %%
from typing import TypedDict

# %%
class Person(TypedDict):
    name :str
    age :int

# %%
p1 : Person = {'name':"abc",
               'age' : 15}

print(p1)
# Out:
# {'name': 'abc', 'age': 15}
