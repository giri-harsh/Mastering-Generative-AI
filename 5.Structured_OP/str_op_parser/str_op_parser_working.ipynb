# %%
from langchain_huggingface import HuggingFaceEndpoint,ChatHuggingFace
from dotenv import load_dotenv
from langchain_core.prompts import PromptTemplate
from langchain_core.output_parsers import StrOutputParser

# %%
load_dotenv()
# Out:
# True

# %%
llm = HuggingFaceEndpoint(
    repo_id="TinyLlama/TinyLlama-1.1B-Chat-v1.0",
    task="text-generation",
    huggingfacehub_api_token="lol"
)

model= ChatHuggingFace(
    llm=llm
)

# %%
#prompt1
temp1 = PromptTemplate(
    template="Write a 3 line report on a {topic}",
    input_variables=['topic'] 
)


#prompt2
temp2 = PromptTemplate(
    template="Write a 4 line summary on following text :  {text}",
    input_variables=['text'] 
)

# %%
parser = StrOutputParser()

# %%
chain = temp1 | model | parser| temp2 |model|parser
result = chain.invoke({'topic':"black hole"})
print(result)
# Out:
# The report "Investigating The Physics and Detection of Black Holes" provides a 3-line summary of the ongoing research on black holes, including their formation, properties, and detection techniques.
#
# 1. Formation of Black Holes
#
# According to relativity theory, the formation of a black hole is a result of the collapse of a massive object, such as a star or a galaxy. The process begins when the object reaches a singularity, where the curvature of space-time becomes infinite, causing the object to collapse into a singularity.
#
# Astronomers have various detectors that can detect black holes, including:
#
# - Gravitational wave detectors: These detectors can observe the gravitational waves emanating from the event horizon of a black hole, triggering the detection and confirmation of their existence.
# - X-ray and gamma-ray telescopes: These telescopes detect radiation emanating from accreting matter at the event horizon of a black hole, confirming their existence.
# - Radio telescopes: These telescopes detect low-frequency radio emissions emanating from the event horizon of a black hole, which confirm their presence.
#
# 2. Properties of Black Holes
#
# Black holes have a unique property that makes them interesting objects of study. They are immensely dense and concentrated objects with more than one million times the mass of the Sun. Their mass is so high that even light from a distance cannot escape from their event horizon, making them unobservable.
#
# Black holes also have a strong gravitational field, which gives rise to a range of phenomena, such as black hole accretion disks, magnetorotational waves, and Einstein-Rosen bridges.
#
# 3. Detection Techniques
#
# Black hole detections are a complex process that requires a variety of techniques. Gravitational waves detectors, such as LIGO and VIRGO, detect gravitational waves from the process of accretion disks and magnetorotational waves caused by black holes. Radio telescopes detect low-frequency radio emissions emanating from the event horizon of a black hole, and X-ray and gamma-ray telescopes detect radiation emanating from accreting matter at the event horizon of a black hole.
