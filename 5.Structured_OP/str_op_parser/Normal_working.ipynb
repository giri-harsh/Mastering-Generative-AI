# %%
from langchain_huggingface import HuggingFaceEndpoint,ChatHuggingFace
from dotenv import load_dotenv
from langchain_core.prompts import PromptTemplate

# %%
load_dotenv()
# Out:
# True

# %%
llm = HuggingFaceEndpoint(
    repo_id="TinyLlama/TinyLlama-1.1B-Chat-v1.0",
    task="text-generation",
    huggingfacehub_api_token=" "
)

# %%
model = ChatHuggingFace(llm=llm)

# %% [markdown]
# ### 1st prompt -> Detailed Report

# %%
temp1 = PromptTemplate(
    template="Write a detailed report on a {topic}",
    input_variables=['topic']
)

# %% [markdown]
# ### 2nd prompt -> Summary

# %%
temp2 = PromptTemplate(
    template="Write a 5 line summary on the following text. Report on {text}",
    input_variables=['text']
)

# %%
prompt1 = temp1.invoke({'topic' : 'black hole'})
result = model.invoke(prompt1)

prompt2 = temp2.invoke({'text':result.content})
result2 = model.invoke(prompt2)

print(result2.content)
# Out:
# This report examines the properties and nature of black holes, including their mass, radius, accretion disk, event horizon, and spherical shape. It discusses the unique features of black holes and how they have been studied through telescopic and observational techniques.
#
# Properties of Black Holes:
#
# 1. Mass: Black holes have a mass equivalent to the mass of a large planet or a star. The gravity of a black hole can be controlled by its mass and radius.
#
# 2. Radius: Black holes are known as supermassive or subatomic black holes depending on their mass. A supermassive black hole has a radius of 1 billion kilometers, while a subatomic black hole has a radius of a million kilometers.
#
# 3. Accretion Disk: As the matter and energy are accumulated by a black hole, it forms an accretion disk. This disk is a region of the event horizon where the gravitational pull becomes so strong that matter cannot escape.
#
# 4. Event Horizon: The event horizon is the boundary of a black hole's location, where the gravitational pull is so strong that everything in its immediate vicinity becomes unstable.
#
# Properties of Black Holes:
#
# 1. Spherical Shape: Black holes have a spherical shape with a singularity at the center. The singularity is a point at which the curvature of space becomes infinite.
#
# 2. Stability: Black holes are known to be stable, meaning they emit no radiation and they will continue to exist until they are destroyed by the collision of other objects or by their own gravity.
#
# 3. Accretion of Matter: Black holes can be the sites of intense accretion, causing them to emit radiation and form new phenomena.
#
# 4. Gravitational Waves: Black holes can produce gravitational waves, which are ripples in the fabric of space-time. These waves can be detected by telescopes, such as LIGO and Virgo.
#
# Conclusion:
#
# Black holes are fascinating and complex celestial objects that have intrigued astronomers and physicists for centuries. They exhibit unique and fascinating properties, including their mass, size, shape, accretion, and the effects of gravity on surrounding space. These properties have led to numerous observations, telescopic and observational techniques, and several theories about the
